# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Scraping

# %%
import requests
import csv
import time
import os

GITHUB_API_URL = "https://api.github.com"
GITHUB_TOKEN = os.getenv("GITHUB_TOKEN") 

HEADERS = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

USER_FIELDS = ["login", "name", "company", "location", "email", "hireable", "bio", 
               "public_repos", "followers", "following", "created_at"]
REPO_FIELDS = ["login", "full_name", "created_at", "stargazers_count", 
               "watchers_count", "language", "has_projects", "has_wiki", "license_name"]

def fetch_users(location, min_followers):
    users = []
    page = 1
    print("Fetching users...")

    while True:
        try:
            response = requests.get(
                f"{GITHUB_API_URL}/search/users",
                headers=HEADERS,
                params={"q": f"location:{location} followers:>{min_followers}", "page": page, "per_page": 30}
            )
            if response.status_code != 200:
                print(f"Error fetching users: {response.status_code}, {response.json().get('message')}")
                break
            
            data = response.json()
            if 'items' not in data or len(data['items']) == 0:
                print("No more users found.")
                break

            users.extend(data['items'])
            print(f"Page {page} fetched. Total users collected: {len(users)}")
            page += 1
            time.sleep(1)  

        except Exception as e:
            print(f"An error occurred while fetching users: {e}")
            break

    return users

def fetch_user_details(login):
    try:
        response = requests.get(f"{GITHUB_API_URL}/users/{login}", headers=HEADERS)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error fetching details for {login}: {response.json().get('message')}")
            return {}
    except Exception as e:
        print(f"An error occurred while fetching details for {login}: {e}")
        return {}

def fetch_user_repositories(login):
    repos = []
    page = 1
    print(f"Fetching repositories for {login}...")

    while True:
        try:
            response = requests.get(
                f"{GITHUB_API_URL}/users/{login}/repos",
                headers=HEADERS,
                params={"sort": "pushed", "page": page, "per_page": 100}
            )
            if response.status_code != 200:
                print(f"Error fetching repositories for {login}: {response.json().get('message')}")
                break
            
            data = response.json()
            if len(data) == 0:
                break

            repos.extend(data)
            print(f"Page {page} of repositories for {login} fetched.")
            page += 1
            time.sleep(1)

            if len(repos) >= 500:
                break

        except Exception as e:
            print(f"An error occurred while fetching repos for {login}: {e}")
            break

    return repos[:500]

def clean_company_name(company):
    return company.strip().lstrip('@').upper() if company else ""

def write_users_to_csv(users):
    with open("users.csv", "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=USER_FIELDS)
        writer.writeheader()
        for user in users:
            writer.writerow({
                "login": user.get("login", ""),
                "name": user.get("name", ""),
                "company": clean_company_name(user.get("company", "")),
                "location": user.get("location", ""),
                "email": user.get("email", ""),
                "hireable": user.get("hireable", ""),
                "bio": user.get("bio", ""),
                "public_repos": user.get("public_repos", 0),
                "followers": user.get("followers", 0),
                "following": user.get("following", 0),
                "created_at": user.get("created_at", "")
            })

def write_repositories_to_csv(repositories):
    with open("repositories.csv", "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=REPO_FIELDS)
        writer.writeheader()
        for repo in repositories:
            writer.writerow({
                "login": repo["owner"]["login"],
                "full_name": repo.get("full_name", ""),
                "created_at": repo.get("created_at", ""),
                "stargazers_count": repo.get("stargazers_count", 0),
                "watchers_count": repo.get("watchers_count", 0),
                "language": repo.get("language", ""),
                "has_projects": repo.get("has_projects", False),
                "has_wiki": repo.get("has_wiki", False),
                "license_name": repo.get("license", {}).get("key", "") if repo.get("license") else ""
            })

def main():
    users = fetch_users('Basel', 10)
    user_details = [fetch_user_details(user["login"]) for user in users]

    write_users_to_csv(user_details)

    all_repositories = []
    for user in user_details:
        login = user["login"]
        repos = fetch_user_repositories(login)
        all_repositories.extend(repos)

    write_repositories_to_csv(all_repositories)
    print("Data scraping completed.")

if __name__ == "__main__":
    main()
# Out:
# Fetching users...
# Page 1 fetched. Total users collected: 30
# Page 2 fetched. Total users collected: 60
# Page 3 fetched. Total users collected: 90
# Page 4 fetched. Total users collected: 120
# Page 5 fetched. Total users collected: 150
# Page 6 fetched. Total users collected: 180
# Page 7 fetched. Total users collected: 210
# Page 8 fetched. Total users collected: 240
# Page 9 fetched. Total users collected: 270
# Page 10 fetched. Total users collected: 300
# Page 11 fetched. Total users collected: 330
# Page 12 fetched. Total users collected: 349
# No more users found.
# Fetching repositories for tarsius...
# Page 1 of repositories for tarsius fetched.
# Fetching repositories for aalmiray...
# Page 1 of repositories for aalmiray fetched.
# Page 2 of repositories for aalmiray fetched.
# Page 3 of repositories for aalmiray fetched.
# Fetching repositories for marcoroth...
# Page 1 of repositories for marcoroth fetched.
# Page 2 of repositories for marcoroth fetched.
# Fetching repositories for klmr...
# Page 1 of repositories for klmr fetched.
# Page 2 of repositories for klmr fetched.
# Fetching repositories for MrNeRF...
# Page 1 of repositories for MrNeRF fetched.
# Fetching repositories for dpryan79...
# Page 1 of repositories for dpryan79 fetched.
# Page 2 of repositories for dpryan79 fetched.
# Page 3 of repositories for dpryan79 fetched.
# Page 4 of repositories for dpryan79 fetched.
# Page 5 of repositories for dpryan79 fetched.
# Fetching repositories for ParthS007...
# Page 1 of repositories for ParthS007 fetched.
# Fetching repositories for quantumjim...
# Page 1 of repositories for quantumjim fetched.
# Fetching repositories for odan...
# Page 1 of repositories for odan fetched.
# Fetching repositories for JuergenGutsch...
# Page 1 of repositories for JuergenGutsch fetched.
# Fetching repositories for v7b1...
# Page 1 of repositories for v7b1 fetched.
# Fetching repositories for a-r-j...
# Page 1 of repositories for a-r-j fetched.
# Fetching repositories for fzenke...
# Page 1 of repositories for fzenke fetched.
# Fetching repositories for eleanor-em...
# Page 1 of repositories for eleanor-em fetched.
# Fetching repositories for dengemann...
# Page 1 of repositories for dengemann fetched.
# Fetching repositories for imagejan...
# Page 1 of repositories for imagejan fetched.
# Page 2 of repositories for imagejan fetched.
# Fetching repositories for charnley...
# Page 1 of repositories for charnley fetched.
# Fetching repositories for rneher...
# Page 1 of repositories for rneher fetched.
# Fetching repositories for syzer...
# Page 1 of repositories for syzer fetched.
# Page 2 of repositories for syzer fetched.
# Page 3 of repositories for syzer fetched.
# Page 4 of repositories for syzer fetched.
# Page 5 of repositories for syzer fetched.
# Fetching repositories for jkarni...
# Page 1 of repositories for jkarni fetched.
# Page 2 of repositories for jkarni fetched.
# Fetching repositories for maehr...
# Page 1 of repositories for maehr fetched.
# Fetching repositories for galderz...
# Page 1 of repositories for galderz fetched.
# Page 2 of repositories for galderz fetched.
# Page 3 of repositories for galderz fetched.
# Fetching repositories for wasserth...
# Page 1 of repositories for wasserth fetched.
# Fetching repositories for ahankinson...
# Page 1 of repositories for ahankinson fetched.
# Fetching repositories for underdoeg...
# Page 1 of repositories for underdoeg fetched.
# Page 2 of repositories for underdoeg fetched.
# Fetching repositories for maysam...
# Page 1 of repositories for maysam fetched.
# Page 2 of repositories for maysam fetched.
# Fetching repositories for yperbasis...
# Page 1 of repositories for yperbasis fetched.
# Fetching repositories for alexarnimueller...
# Page 1 of repositories for alexarnimueller fetched.
# Fetching repositories for MaxGfeller...
# Page 1 of repositories for MaxGfeller fetched.
# Page 2 of repositories for MaxGfeller fetched.
# Fetching repositories for andersx...
# Page 1 of repositories for andersx fetched.
# Fetching repositories for neocorp...
# Page 1 of repositories for neocorp fetched.
# Fetching repositories for raducotescu...
# Page 1 of repositories for raducotescu fetched.
# Fetching repositories for bar9...
# Page 1 of repositories for bar9 fetched.
# Fetching repositories for undeadpixel...
# Page 1 of repositories for undeadpixel fetched.
# Fetching repositories for marcantondahmen...
# Page 1 of repositories for marcantondahmen fetched.
# Fetching repositories for ravage84...
# Page 1 of repositories for ravage84 fetched.
# Page 2 of repositories for ravage84 fetched.
# Fetching repositories for gabrielwalt...
# Page 1 of repositories for gabrielwalt fetched.
# Fetching repositories for elanmart...
# Page 1 of repositories for elanmart fetched.
# Fetching repositories for JeyDi...
# Page 1 of repositories for JeyDi fetched.
# Fetching repositories for tbreuss...
# Page 1 of repositories for tbreuss fetched.
# Fetching repositories for Phlya...
# Page 1 of repositories for Phlya fetched.
# Fetching repositories for eyenx...
# Page 1 of repositories for eyenx fetched.
# Page 2 of repositories for eyenx fetched.
# Fetching repositories for ioolkos...
# Page 1 of repositories for ioolkos fetched.
# Page 2 of repositories for ioolkos fetched.
# Page 3 of repositories for ioolkos fetched.
# Fetching repositories for dergraf...
# Page 1 of repositories for dergraf fetched.
# Fetching repositories for quadbiolab...
# Fetching repositories for Accio...
# Page 1 of repositories for Accio fetched.
# Page 2 of repositories for Accio fetched.
# Fetching repositories for ftiff...
# Page 1 of repositories for ftiff fetched.
# Fetching repositories for atenagm1375...
# Page 1 of repositories for atenagm1375 fetched.
# Fetching repositories for danvet...
# Page 1 of repositories for danvet fetched.
# Fetching repositories for daminetreg...
# Page 1 of repositories for daminetreg fetched.
# Fetching repositories for pvillega...
# Page 1 of repositories for pvillega fetched.
# Page 2 of repositories for pvillega fetched.
# Fetching repositories for larshesel...
# Page 1 of repositories for larshesel fetched.
# Fetching repositories for siers...
# Page 1 of repositories for siers fetched.
# Fetching repositories for shernshiou...
# Page 1 of repositories for shernshiou fetched.
# Fetching repositories for jv-k...
# Page 1 of repositories for jv-k fetched.
# Fetching repositories for neherlab...
# Page 1 of repositories for neherlab fetched.
# Fetching repositories for cbg-ethz...
# Page 1 of repositories for cbg-ethz fetched.
# Fetching repositories for nbara...
# Page 1 of repositories for nbara fetched.
# Fetching repositories for uniqueg...
# Page 1 of repositories for uniqueg fetched.
# Fetching repositories for marcelluethi...
# Page 1 of repositories for marcelluethi fetched.
# Fetching repositories for Marius1311...
# Page 1 of repositories for Marius1311 fetched.
# Fetching repositories for mo271...
# Page 1 of repositories for mo271 fetched.
# Fetching repositories for dkgaraujo...
# Page 1 of repositories for dkgaraujo fetched.
# Fetching repositories for hackermd...
# Page 1 of repositories for hackermd fetched.
# Fetching repositories for bennyzen...
# Page 1 of repositories for bennyzen fetched.
# Fetching repositories for lucafluri...
# Page 1 of repositories for lucafluri fetched.
# Fetching repositories for deepakunni3...
# Page 1 of repositories for deepakunni3 fetched.
# Fetching repositories for greenore...
# Page 1 of repositories for greenore fetched.
# Fetching repositories for fgypas...
# Page 1 of repositories for fgypas fetched.
# Fetching repositories for esteban-aliverti...
# Page 1 of repositories for esteban-aliverti fetched.
# Fetching repositories for hirsch88...
# Page 1 of repositories for hirsch88 fetched.
# Fetching repositories for netzwerg...
# Page 1 of repositories for netzwerg fetched.
# Fetching repositories for QTimort...
# Page 1 of repositories for QTimort fetched.
# Fetching repositories for goggle...
# Page 1 of repositories for goggle fetched.
# Page 2 of repositories for goggle fetched.
# Fetching repositories for appcell...
# Page 1 of repositories for appcell fetched.
# Fetching repositories for ppmathis...
# Page 1 of repositories for ppmathis fetched.
# Fetching repositories for rukshn...
# Page 1 of repositories for rukshn fetched.
# Fetching repositories for epijim...
# Page 1 of repositories for epijim fetched.
# Page 2 of repositories for epijim fetched.
# Fetching repositories for nilseling...
# Page 1 of repositories for nilseling fetched.
# Fetching repositories for acollign...
# Page 1 of repositories for acollign fetched.
# Fetching repositories for jeeberhardt...
# Page 1 of repositories for jeeberhardt fetched.
# Fetching repositories for D4rkMindz...
# Page 1 of repositories for D4rkMindz fetched.
# Fetching repositories for adobe-rnd...
# Page 1 of repositories for adobe-rnd fetched.
# Fetching repositories for dweber019...
# Page 1 of repositories for dweber019 fetched.
# Fetching repositories for markh0rr...
# Page 1 of repositories for markh0rr fetched.
# Fetching repositories for pedrofale...
# Page 1 of repositories for pedrofale fetched.
# Fetching repositories for laduplessis...
# Page 1 of repositories for laduplessis fetched.
# Fetching repositories for etiiiR...
# Page 1 of repositories for etiiiR fetched.
# Page 2 of repositories for etiiiR fetched.
# Fetching repositories for areyesq89...
# Page 1 of repositories for areyesq89 fetched.
# Fetching repositories for TK5-Tim...
# Page 1 of repositories for TK5-Tim fetched.
# Fetching repositories for leonden...
# Page 1 of repositories for leonden fetched.
# Fetching repositories for almilo...
# Page 1 of repositories for almilo fetched.
# Fetching repositories for wingsuitist...
# Page 1 of repositories for wingsuitist fetched.
# Fetching repositories for guylabs...
# Page 1 of repositories for guylabs fetched.
# Fetching repositories for schoentoon...
# Page 1 of repositories for schoentoon fetched.
# Fetching repositories for laurafontanesi...
# Page 1 of repositories for laurafontanesi fetched.
# Fetching repositories for wheresvic...
# Page 1 of repositories for wheresvic fetched.
# Fetching repositories for idris-maps...
# Page 1 of repositories for idris-maps fetched.
# Page 2 of repositories for idris-maps fetched.
# Fetching repositories for caoimhechaos...
# Page 1 of repositories for caoimhechaos fetched.
# Fetching repositories for marcossegovia...
# Page 1 of repositories for marcossegovia fetched.
# Page 2 of repositories for marcossegovia fetched.
# Fetching repositories for SwissTPH...
# Page 1 of repositories for SwissTPH fetched.
# Fetching repositories for delcroip...
# Page 1 of repositories for delcroip fetched.
# Fetching repositories for fabwu...
# Page 1 of repositories for fabwu fetched.
# Fetching repositories for alternatex...
# Page 1 of repositories for alternatex fetched.
# Fetching repositories for andreasfink...
# Page 1 of repositories for andreasfink fetched.
# Fetching repositories for felixmichel...
# Page 1 of repositories for felixmichel fetched.
# Fetching repositories for dev7ch...
# Page 1 of repositories for dev7ch fetched.
# Fetching repositories for gmickel...
# Page 1 of repositories for gmickel fetched.
# Fetching repositories for jordanlepera...
# Page 1 of repositories for jordanlepera fetched.
# Fetching repositories for musicEnfanthen...
# Page 1 of repositories for musicEnfanthen fetched.
# Fetching repositories for guma44...
# Page 1 of repositories for guma44 fetched.
# Fetching repositories for fmi-basel...
# Page 1 of repositories for fmi-basel fetched.
# Fetching repositories for mstritt...
# Page 1 of repositories for mstritt fetched.
# Fetching repositories for seakayone...
# Page 1 of repositories for seakayone fetched.
# Fetching repositories for jonnybbb...
# Page 1 of repositories for jonnybbb fetched.
# Fetching repositories for danon6868...
# Page 1 of repositories for danon6868 fetched.
# Fetching repositories for valentinorusconi...
# Page 1 of repositories for valentinorusconi fetched.
# Fetching repositories for yguenduez...
# Page 1 of repositories for yguenduez fetched.
# Fetching repositories for alexcarol...
# Page 1 of repositories for alexcarol fetched.
# Fetching repositories for Tiim...
# Page 1 of repositories for Tiim fetched.
# Fetching repositories for andreas-aeschlimann...
# Page 1 of repositories for andreas-aeschlimann fetched.
# Fetching repositories for extrapixel...
# Page 1 of repositories for extrapixel fetched.
# Fetching repositories for rdrighetto...
# Page 1 of repositories for rdrighetto fetched.
# Fetching repositories for codingluke...
# Page 1 of repositories for codingluke fetched.
# Fetching repositories for young24...
# Page 1 of repositories for young24 fetched.
# Fetching repositories for BaselHack...
# Page 1 of repositories for BaselHack fetched.
# Fetching repositories for dulvac...
# Page 1 of repositories for dulvac fetched.
# Fetching repositories for ofajardo...
# Page 1 of repositories for ofajardo fetched.
# Fetching repositories for shoeferlin...
# Page 1 of repositories for shoeferlin fetched.
# Fetching repositories for basecode...
# Page 1 of repositories for basecode fetched.
# Fetching repositories for sechidis...
# Page 1 of repositories for sechidis fetched.
# Fetching repositories for thedatadudech...
# Page 1 of repositories for thedatadudech fetched.
# Fetching repositories for j3mdamas...
# Page 1 of repositories for j3mdamas fetched.
# Fetching repositories for joshy...
# Page 1 of repositories for joshy fetched.
# Fetching repositories for occelebi...
# Page 1 of repositories for occelebi fetched.
# Fetching repositories for xrobin...
# Page 1 of repositories for xrobin fetched.
# Fetching repositories for mmlr...
# Page 1 of repositories for mmlr fetched.
# Fetching repositories for vladen...
# Page 1 of repositories for vladen fetched.
# Fetching repositories for gtancev...
# Page 1 of repositories for gtancev fetched.
# Fetching repositories for loopasam...
# Page 1 of repositories for loopasam fetched.
# Fetching repositories for baloise...
# Page 1 of repositories for baloise fetched.
# Page 2 of repositories for baloise fetched.
# Fetching repositories for gysel...
# Page 1 of repositories for gysel fetched.
# Fetching repositories for amaunz...
# Page 1 of repositories for amaunz fetched.
# Fetching repositories for thsmit...
# Page 1 of repositories for thsmit fetched.
# Fetching repositories for ddresch...
# Page 1 of repositories for ddresch fetched.
# Fetching repositories for juergba...
# Page 1 of repositories for juergba fetched.
# Fetching repositories for rordi...
# Page 1 of repositories for rordi fetched.
# Fetching repositories for MikeJSeo...
# Page 1 of repositories for MikeJSeo fetched.
# Fetching repositories for lev1nn...
# Page 1 of repositories for lev1nn fetched.
# Fetching repositories for LuSchumacher...
# Page 1 of repositories for LuSchumacher fetched.
# Fetching repositories for fiscafusca...
# Page 1 of repositories for fiscafusca fetched.
# Fetching repositories for humford...
# Page 1 of repositories for humford fetched.
# Fetching repositories for fabriziofortino...
# Page 1 of repositories for fabriziofortino fetched.
# Fetching repositories for francescomari...
# Page 1 of repositories for francescomari fetched.
# Fetching repositories for culmat...
# Page 1 of repositories for culmat fetched.
# Page 2 of repositories for culmat fetched.
# Fetching repositories for janfaessler...
# Page 1 of repositories for janfaessler fetched.
# Fetching repositories for yalais...
# Page 1 of repositories for yalais fetched.
# Fetching repositories for bethany-j-allen...
# Page 1 of repositories for bethany-j-allen fetched.
# Fetching repositories for byeungchun...
# Page 1 of repositories for byeungchun fetched.
# Fetching repositories for guenterh...
# Page 1 of repositories for guenterh fetched.
# Fetching repositories for zhisonghe...
# Page 1 of repositories for zhisonghe fetched.
# Fetching repositories for revitron...
# Page 1 of repositories for revitron fetched.
# Fetching repositories for jaulz...
# Page 1 of repositories for jaulz fetched.
# Page 2 of repositories for jaulz fetched.
# Fetching repositories for bailliem...
# Page 1 of repositories for bailliem fetched.
# Fetching repositories for mgje...
# Page 1 of repositories for mgje fetched.
# Fetching repositories for yschindel...
# Page 1 of repositories for yschindel fetched.
# Fetching repositories for Seryusjj...
# Page 1 of repositories for Seryusjj fetched.
# Fetching repositories for fmeschbe...
# Page 1 of repositories for fmeschbe fetched.
# Fetching repositories for paolomoz...
# Page 1 of repositories for paolomoz fetched.
# Fetching repositories for tertek...
# Page 1 of repositories for tertek fetched.
# Fetching repositories for TheMaaarc...
# Page 1 of repositories for TheMaaarc fetched.
# Fetching repositories for ingmars...
# Page 1 of repositories for ingmars fetched.
# Fetching repositories for Sparclex...
# Page 1 of repositories for Sparclex fetched.
# Fetching repositories for delalamo...
# Page 1 of repositories for delalamo fetched.
# Fetching repositories for bull0n...
# Page 1 of repositories for bull0n fetched.
# Fetching repositories for tholu...
# Page 1 of repositories for tholu fetched.
# Page 2 of repositories for tholu fetched.
# Fetching repositories for cfi2017...
# Page 1 of repositories for cfi2017 fetched.
# Fetching repositories for mmolari...
# Page 1 of repositories for mmolari fetched.
# Fetching repositories for AmarTabakovic...
# Page 1 of repositories for AmarTabakovic fetched.
# Fetching repositories for csmuller...
# Page 1 of repositories for csmuller fetched.
# Fetching repositories for kordamp...
# Page 1 of repositories for kordamp fetched.
# Fetching repositories for magnolia-cms...
# Page 1 of repositories for magnolia-cms fetched.
# Fetching repositories for cdedonno...
# Page 1 of repositories for cdedonno fetched.
# Fetching repositories for paulheyer...
# Page 1 of repositories for paulheyer fetched.
# Fetching repositories for ge11232002...
# Page 1 of repositories for ge11232002 fetched.
# Fetching repositories for StanBarrows...
# Page 1 of repositories for StanBarrows fetched.
# Fetching repositories for gregorLen...
# Page 1 of repositories for gregorLen fetched.
# Fetching repositories for cwoffenden...
# Page 1 of repositories for cwoffenden fetched.
# Fetching repositories for andreagrioni...
# Page 1 of repositories for andreagrioni fetched.
# Fetching repositories for mjmurphy...
# Page 1 of repositories for mjmurphy fetched.
# Fetching repositories for ekremney...
# Page 1 of repositories for ekremney fetched.
# Fetching repositories for j-keck...
# Page 1 of repositories for j-keck fetched.
# Fetching repositories for BBQuercus...
# Page 1 of repositories for BBQuercus fetched.
# Fetching repositories for zakgreant...
# Page 1 of repositories for zakgreant fetched.
# Fetching repositories for Joel-Schaltenbrand...
# Page 1 of repositories for Joel-Schaltenbrand fetched.
# Fetching repositories for editio...
# Page 1 of repositories for editio fetched.
# Fetching repositories for KasparJohannesSchneider...
# Page 1 of repositories for KasparJohannesSchneider fetched.
# Fetching repositories for brain-tec...
# Page 1 of repositories for brain-tec fetched.
# Page 2 of repositories for brain-tec fetched.
# Fetching repositories for Ghazi-Bouabene...
# Page 1 of repositories for Ghazi-Bouabene fetched.
# Fetching repositories for BalduinLandolt...
# Page 1 of repositories for BalduinLandolt fetched.
# Fetching repositories for Ariwor...
# Page 1 of repositories for Ariwor fetched.
# Fetching repositories for mhueser...
# Fetching repositories for SoapZA...
# Page 1 of repositories for SoapZA fetched.
# Fetching repositories for JanaJarecki...
# Page 1 of repositories for JanaJarecki fetched.
# Fetching repositories for nfq...
# Page 1 of repositories for nfq fetched.
# Fetching repositories for cjelger...
# Page 1 of repositories for cjelger fetched.
# Fetching repositories for Billy-Nie...
# Page 1 of repositories for Billy-Nie fetched.
# Fetching repositories for EricBoittier...
# Page 1 of repositories for EricBoittier fetched.
# Fetching repositories for netzarbeiter...
# Page 1 of repositories for netzarbeiter fetched.
# Fetching repositories for tikiatua...
# Page 1 of repositories for tikiatua fetched.
# Fetching repositories for siyabendoezdemir...
# Page 1 of repositories for siyabendoezdemir fetched.
# Fetching repositories for samuelnbaumer...
# Page 1 of repositories for samuelnbaumer fetched.
# Fetching repositories for Smeyke...
# Page 1 of repositories for Smeyke fetched.
# Fetching repositories for codrinbucur...
# Page 1 of repositories for codrinbucur fetched.
# Fetching repositories for sschuepbach...
# Page 1 of repositories for sschuepbach fetched.
# Fetching repositories for decodoku...
# Page 1 of repositories for decodoku fetched.
# Fetching repositories for winklerrr...
# Page 1 of repositories for winklerrr fetched.
# Fetching repositories for baloise-incubator...
# Page 1 of repositories for baloise-incubator fetched.
# Fetching repositories for eggerdo...
# Page 1 of repositories for eggerdo fetched.
# Fetching repositories for pietropatelli...
# Page 1 of repositories for pietropatelli fetched.
# Fetching repositories for rolandschaub...
# Page 1 of repositories for rolandschaub fetched.
# Fetching repositories for Aaronmacaron...
# Page 1 of repositories for Aaronmacaron fetched.
# Fetching repositories for adrinamin...
# Page 1 of repositories for adrinamin fetched.
# Fetching repositories for topherzee...
# Page 1 of repositories for topherzee fetched.
# Fetching repositories for cstringer17...
# Page 1 of repositories for cstringer17 fetched.
# Fetching repositories for iamdamla...
# Page 1 of repositories for iamdamla fetched.
# Fetching repositories for janexner...
# Page 1 of repositories for janexner fetched.
# Fetching repositories for aibasel...
# Page 1 of repositories for aibasel fetched.
# Fetching repositories for tehrhart...
# Page 1 of repositories for tehrhart fetched.
# Fetching repositories for AlbertPorres...
# Page 1 of repositories for AlbertPorres fetched.
# Fetching repositories for muenchto...
# Page 1 of repositories for muenchto fetched.
# Fetching repositories for ursjoss...
# Page 1 of repositories for ursjoss fetched.
# Fetching repositories for rodrigo-pena...
# Page 1 of repositories for rodrigo-pena fetched.
# Fetching repositories for moritztim...
# Page 1 of repositories for moritztim fetched.
# Fetching repositories for jsurkont...
# Page 1 of repositories for jsurkont fetched.
# Fetching repositories for yannickholzenkamp...
# Page 1 of repositories for yannickholzenkamp fetched.
# Fetching repositories for brunosaboia...
# Page 1 of repositories for brunosaboia fetched.
# Fetching repositories for sebherbert...
# Page 1 of repositories for sebherbert fetched.
# Fetching repositories for c-bik...
# Page 1 of repositories for c-bik fetched.
# Fetching repositories for LeonardoLupori...
# Page 1 of repositories for LeonardoLupori fetched.
# Fetching repositories for subotic...
# Page 1 of repositories for subotic fetched.
# Page 2 of repositories for subotic fetched.
# Fetching repositories for chrede88...
# Page 1 of repositories for chrede88 fetched.
# Fetching repositories for AronBA...
# Page 1 of repositories for AronBA fetched.
# Fetching repositories for JanSchlender...
# Page 1 of repositories for JanSchlender fetched.
# Fetching repositories for duynguyen...
# Page 1 of repositories for duynguyen fetched.
# Fetching repositories for benhendriks...
# Page 1 of repositories for benhendriks fetched.
# Fetching repositories for StefanThoma...
# Page 1 of repositories for StefanThoma fetched.
# Fetching repositories for RamiDaoud1979-zz...
# Page 1 of repositories for RamiDaoud1979-zz fetched.
# Fetching repositories for RPanczak...
# Page 1 of repositories for RPanczak fetched.
# Fetching repositories for GlitchedPolygons...
# Page 1 of repositories for GlitchedPolygons fetched.
# Fetching repositories for SyarifZapata...
# Page 1 of repositories for SyarifZapata fetched.
# Fetching repositories for hodcroftlab...
# Page 1 of repositories for hodcroftlab fetched.
# Fetching repositories for eva-j...
# Page 1 of repositories for eva-j fetched.
# Fetching repositories for MDendura...
# Page 1 of repositories for MDendura fetched.
# Fetching repositories for PaulRitsche...
# Page 1 of repositories for PaulRitsche fetched.
# Fetching repositories for maxfrischknecht...
# Page 1 of repositories for maxfrischknecht fetched.
# Fetching repositories for laszlolukacs...
# Page 1 of repositories for laszlolukacs fetched.
# Fetching repositories for Dufry...
# Page 1 of repositories for Dufry fetched.
# Fetching repositories for ivanek...
# Page 1 of repositories for ivanek fetched.
# Fetching repositories for daniel-fink-de...
# Page 1 of repositories for daniel-fink-de fetched.
# Fetching repositories for rahelarnold98...
# Page 1 of repositories for rahelarnold98 fetched.
# Fetching repositories for cyon...
# Page 1 of repositories for cyon fetched.
# Fetching repositories for svene...
# Page 1 of repositories for svene fetched.
# Fetching repositories for kptdobe...
# Page 1 of repositories for kptdobe fetched.
# Page 2 of repositories for kptdobe fetched.
# Fetching repositories for dassi...
# Page 1 of repositories for dassi fetched.
# Fetching repositories for niiku...
# Page 1 of repositories for niiku fetched.
# Fetching repositories for mfalland...
# Page 1 of repositories for mfalland fetched.
# Fetching repositories for bundfussr...
# Page 1 of repositories for bundfussr fetched.
# Fetching repositories for jonock...
# Page 1 of repositories for jonock fetched.
# Fetching repositories for riccardolardi...
# Page 1 of repositories for riccardolardi fetched.
# Fetching repositories for didierCH...
# Page 1 of repositories for didierCH fetched.
# Fetching repositories for pascscha...
# Page 1 of repositories for pascscha fetched.
# Fetching repositories for rivella50...
# Page 1 of repositories for rivella50 fetched.
# Fetching repositories for ptmerz...
# Page 1 of repositories for ptmerz fetched.
# Fetching repositories for McKean...
# Page 1 of repositories for McKean fetched.
# Fetching repositories for aschwanb...
# Page 1 of repositories for aschwanb fetched.
# Fetching repositories for yesil...
# Page 1 of repositories for yesil fetched.
# Fetching repositories for mopore...
# Page 1 of repositories for mopore fetched.
# Fetching repositories for thiemo...
# Page 1 of repositories for thiemo fetched.
# Fetching repositories for pawelru...
# Page 1 of repositories for pawelru fetched.
# Fetching repositories for arnoldjulian...
# Page 1 of repositories for arnoldjulian fetched.
# Fetching repositories for nimwegenLab...
# Page 1 of repositories for nimwegenLab fetched.
# Fetching repositories for volteanu...
# Page 1 of repositories for volteanu fetched.
# Fetching repositories for simeonjackman...
# Page 1 of repositories for simeonjackman fetched.
# Fetching repositories for JasonShuyinta...
# Page 1 of repositories for JasonShuyinta fetched.
# Fetching repositories for m-l-1...
# Page 1 of repositories for m-l-1 fetched.
# Fetching repositories for moddatherrashed...
# Page 1 of repositories for moddatherrashed fetched.
# Fetching repositories for gdario...
# Page 1 of repositories for gdario fetched.
# Fetching repositories for samuelpulfer...
# Page 1 of repositories for samuelpulfer fetched.
# Fetching repositories for stefan-guggisberg...
# Page 1 of repositories for stefan-guggisberg fetched.
# Fetching repositories for tomaszdurka...
# Page 1 of repositories for tomaszdurka fetched.
# Fetching repositories for Andreas-Forster...
# Page 1 of repositories for Andreas-Forster fetched.
# Fetching repositories for gatoniel...
# Page 1 of repositories for gatoniel fetched.
# Fetching repositories for raffaelschneider...
# Page 1 of repositories for raffaelschneider fetched.
# Fetching repositories for michaelmarth...
# Page 1 of repositories for michaelmarth fetched.
# Fetching repositories for sarahhcarl...
# Page 1 of repositories for sarahhcarl fetched.
# Fetching repositories for Tiliavir...
# Page 1 of repositories for Tiliavir fetched.
# Fetching repositories for nickholway...
# Page 1 of repositories for nickholway fetched.
# Fetching repositories for tph-thuering...
# Page 1 of repositories for tph-thuering fetched.
# Fetching repositories for adelabriere...
# Page 1 of repositories for adelabriere fetched.
# Fetching repositories for martinfuchs...
# Page 1 of repositories for martinfuchs fetched.
# Fetching repositories for LCthur...
# Page 1 of repositories for LCthur fetched.
# Fetching repositories for aurdipas...
# Page 1 of repositories for aurdipas fetched.
# Fetching repositories for alexkarargyris...
# Page 1 of repositories for alexkarargyris fetched.
# Fetching repositories for josip2312...
# Page 1 of repositories for josip2312 fetched.
# Fetching repositories for CodeOneTwo...
# Page 1 of repositories for CodeOneTwo fetched.
# Fetching repositories for JacekKedzierski...
# Page 1 of repositories for JacekKedzierski fetched.
# Fetching repositories for IntiQuan...
# Page 1 of repositories for IntiQuan fetched.
# Fetching repositories for numbersman77...
# Page 1 of repositories for numbersman77 fetched.
# Fetching repositories for timlandolt...
# Page 1 of repositories for timlandolt fetched.
# Fetching repositories for lunatsukiii...
# Page 1 of repositories for lunatsukiii fetched.
# Fetching repositories for AlexRRR...
# Page 1 of repositories for AlexRRR fetched.
# Fetching repositories for flavens...
# Page 1 of repositories for flavens fetched.
# Fetching repositories for doemsche...
# Page 1 of repositories for doemsche fetched.
# Fetching repositories for matteotex91...
# Page 1 of repositories for matteotex91 fetched.
# Fetching repositories for miandovka...
# Page 1 of repositories for miandovka fetched.
# Fetching repositories for CaibinSh...
# Page 1 of repositories for CaibinSh fetched.
# Fetching repositories for AmirEhsan95...
# Page 1 of repositories for AmirEhsan95 fetched.
# Fetching repositories for maltehelmert...
# Page 1 of repositories for maltehelmert fetched.
# Fetching repositories for jnussbaum...
# Page 1 of repositories for jnussbaum fetched.
# Fetching repositories for vtoure...
# Page 1 of repositories for vtoure fetched.
# Fetching repositories for gordonkoehn...
# Page 1 of repositories for gordonkoehn fetched.
# Fetching repositories for kailashnathkutti...
# Page 1 of repositories for kailashnathkutti fetched.
# Fetching repositories for TobiasRoth...
# Page 1 of repositories for TobiasRoth fetched.
# Fetching repositories for mkgl...
# Page 1 of repositories for mkgl fetched.
# Fetching repositories for mtte...
# Page 1 of repositories for mtte fetched.
# Fetching repositories for coatpont...
# Page 1 of repositories for coatpont fetched.
# Fetching repositories for jludwiczak...
# Page 1 of repositories for jludwiczak fetched.
# Fetching repositories for lorenzbr...
# Page 1 of repositories for lorenzbr fetched.
# Fetching repositories for lrosenth...
# Page 1 of repositories for lrosenth fetched.
# Fetching repositories for chrishuan9...
# Page 1 of repositories for chrishuan9 fetched.
# Fetching repositories for pfriedri...
# Page 1 of repositories for pfriedri fetched.
# Fetching repositories for waleedelsayed...
# Page 1 of repositories for waleedelsayed fetched.
# Fetching repositories for MeuwlyGroup...
# Fetching repositories for otayfuroglu...
# Page 1 of repositories for otayfuroglu fetched.
# Fetching repositories for OmarMAshour...
# Page 1 of repositories for OmarMAshour fetched.
# Fetching repositories for JanAdelman...
# Page 1 of repositories for JanAdelman fetched.
# Fetching repositories for alazzaro...
# Page 1 of repositories for alazzaro fetched.
# Fetching repositories for SilenLoc...
# Page 1 of repositories for SilenLoc fetched.
# Fetching repositories for jose-correia...
# Page 1 of repositories for jose-correia fetched.
# Fetching repositories for aroller...
# Page 1 of repositories for aroller fetched.
# Fetching repositories for net-cscience-raphael...
# Page 1 of repositories for net-cscience-raphael fetched.
# Fetching repositories for RidaAyed...
# Page 1 of repositories for RidaAyed fetched.
# Fetching repositories for jarheadcore...
# Page 1 of repositories for jarheadcore fetched.
# Fetching repositories for alvarogonjim...
# Page 1 of repositories for alvarogonjim fetched.
# Fetching repositories for palsch...
# Page 1 of repositories for palsch fetched.
# Fetching repositories for dsolsona...
# Page 1 of repositories for dsolsona fetched.
# Fetching repositories for frieder...
# Page 1 of repositories for frieder fetched.
# Fetching repositories for dpdawson...
# Page 1 of repositories for dpdawson fetched.
# Data scraping completed.

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df
# Out:
#             login                     name               company  \
# 0         tarsius          Jonas Bernoulli                   NaN
# 1        aalmiray           Andres Almiray                   NaN
# 2       marcoroth               Marco Roth                   NaN
# 3            klmr           Konrad Rudolph                 ROCHE
# 4          MrNeRF                  janusch                   NaN
# ..            ...                      ...                   ...
# 344  alvarogonjim  Alvaro Gonzalez-Jimenez   UNIVERSITY OF BASEL
# 345        palsch              Paul Schell  PRODYNA (SCHWEIZ) AG
# 346      dsolsona           Daniel Solsona             BEEKEEPER
# 347       frieder           Frieder Heugel                   NaN
# 348      dpdawson            Daniel Dawson                GOOGLE
#
#                location                     email hireable  \
# 0    Basel, Switzerland          jonas@bernoul.li      NaN
# 1    Basel, Switzerland        aalmiray@gmail.com      NaN
# 2    Basel, Switzerland                       NaN     True
# 3             Basel, CH  konrad.rudolph@gmail.com      NaN
# 4    Basel, Switzerland                       NaN     True
# ..                  ...                       ...      ...
# 344               Basel  alvarogonjim95@gmail.com      NaN
# 345               Basel            pal.sch@gmx.de      NaN
# 346               Basel                       NaN      NaN
# 347  Basel, Switzerland                       NaN      NaN
# 348  Basel, Switzerland     dpdawson@dpdawson.org     True
#
#                                                    bio  public_repos  \
# 0                                                  NaN            39
# 1    I code for fun and help others in the process....           253
# 2    Rubyist, Full-Stack Devloper and Open Source C...           193
# 3    Geneticist 🧬, computer scientist 𝝺 and softwar...           115
# 4    Professional C++ Software Engineer. Skills: CU...            34
# ..                                                 ...           ...
# 344                                                NaN            23
# 345  I am a senior software architect and consultan...            18
# 346                                                NaN            35
# 347                                                NaN            10
# 348                                                NaN            27
#
#      followers  following            created_at
# 0         1345         45  2008-09-17T19:18:37Z
# 1          887         65  2008-06-17T00:30:56Z
# 2          560       1135  2014-01-15T17:12:11Z
# 3          473        109  2008-12-07T20:55:40Z
# 4          438         38  2017-11-21T18:17:58Z
# ..         ...        ...                   ...
# 344         11         11  2017-02-09T17:00:18Z
# 345         11         14  2012-03-21T17:09:18Z
# 346         11          3  2011-06-26T16:07:22Z
# 347         11          0  2011-01-31T10:19:09Z
# 348         11         88  2010-11-16T21:28:17Z
#
# [349 rows x 11 columns]

# %%
import pandas as pd

repositories_df = pd.read_csv("repositories.csv")

repositories_df
# Out:
#           login                full_name            created_at  \
# 0       tarsius            tarsius/llama  2024-08-10T21:22:27Z
# 1       tarsius          tarsius/morlock  2013-06-24T11:07:08Z
# 2       tarsius            tarsius/imake  2017-10-06T11:56:19Z
# 3       tarsius  tarsius/notmuch-maildir  2024-08-05T16:07:12Z
# 4       tarsius          tarsius/bicycle  2017-08-06T11:23:07Z
# ...         ...                      ...                   ...
# 13961  dpdawson  dpdawson/ruby-brainfuck  2013-08-16T10:40:10Z
# 13962  dpdawson           dpdawson/rails  2013-07-07T20:03:35Z
# 13963  dpdawson          dpdawson/dotvim  2013-07-05T22:40:51Z
# 13964  dpdawson        dpdawson/dotfiles  2013-07-09T07:55:09Z
# 13965  dpdawson         dpdawson/sinatra  2013-04-12T18:20:53Z
#
#        stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0                     2               2  Emacs Lisp         False     False
# 1                    13              13  Emacs Lisp         False     False
# 2                     7               7  Emacs Lisp         False     False
# 3                     2               2  Emacs Lisp         False     False
# 4                    59              59  Emacs Lisp         False     False
# ...                 ...             ...         ...           ...       ...
# 13961                 0               0        Ruby          True      True
# 13962                 0               0        Ruby          True     False
# 13963                 0               0        VimL          True      True
# 13964                 0               0       Shell          True     False
# 13965                 0               0        Ruby          True     False
#
#       license_name
# 0          gpl-3.0
# 1          gpl-3.0
# 2          gpl-3.0
# 3          gpl-3.0
# 4          gpl-3.0
# ...            ...
# 13961          NaN
# 13962          NaN
# 13963          NaN
# 13964          mit
# 13965          mit
#
# [13966 rows x 9 columns]

# %% [markdown]
# # Question 1

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

top_5_users = users_df.sort_values(by="followers", ascending=False).head(5)["login"]

top_5_users_list = ",".join(top_5_users)

print(top_5_users_list)
# Out:
# tarsius,aalmiray,marcoroth,klmr,MrNeRF

# %% [markdown]
# # Question 2

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df['created_at'] = pd.to_datetime(users_df['created_at'])

earliest_users = users_df.sort_values(by="created_at", ascending=True).head(5)["login"]

earliest_users_list = ",".join(earliest_users)

print(earliest_users_list)
# Out:
# bennyzen,aalmiray,pvillega,tarsius,amaunz

# %% [markdown]
# # Question 3

# %%
import pandas as pd

repos_df = pd.read_csv("repositories.csv")

valid_licenses = repos_df[repos_df['license_name'] != ""]

top_3_licenses = valid_licenses['license_name'].value_counts().head(3)

top_3_licenses_list = ",".join(top_3_licenses.index)

print(top_3_licenses_list)
# Out:
# mit,apache-2.0,other

# %% [markdown]
# # Question 4

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

company_counts = users_df['company'].value_counts().head(3)

print(company_counts)
# Out:
# company
# ADOBE                  20
# UNIVERSITY OF BASEL    20
# ROCHE                  12
# Name: count, dtype: int64

# %% [markdown]
# # Question 5

# %%
import pandas as pd

repos_df = pd.read_csv("repositories.csv")

repos_df['language'].value_counts().idxmax()
# Out:
# 'JavaScript'

# %% [markdown]
# # Question 6

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df['created_at'] = pd.to_datetime(users_df['created_at'])

recent_users = users_df[users_df['created_at'] > '2020-01-01']

repos_df = pd.read_csv("repositories.csv")

merged_df = repos_df[repos_df['login'].isin(recent_users['login'])]

valid_languages = merged_df[merged_df['language'].notna() & (merged_df['language'] != "")]

language_counts = valid_languages['language'].value_counts()

second_most_popular_language = language_counts.index[1] if len(language_counts) > 1 else None

print(second_most_popular_language)
# Out:
# HTML

# %% [markdown]
# # Question 7

# %%
import pandas as pd

repos_df = pd.read_csv("repositories.csv")

valid_repos = repos_df[repos_df['language'].notna() & (repos_df['language'] != "")]

average_stars = valid_repos.groupby('language')['stargazers_count'].mean()

highest_avg_stars_language = average_stars.idxmax()
highest_avg_stars_count = average_stars.max()

print(highest_avg_stars_language, highest_avg_stars_count)
# Out:
# PureScript 114.0

# %% [markdown]
# # Question 8

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

top_5_leaders = users_df.sort_values(by='leader_strength', ascending=False).head(5)['login']

top_5_leaders_list = ",".join(top_5_leaders)

print(top_5_leaders_list)
# Out:
# dpryan79,wasserth,ravage84,elanmart,quadbiolab

# %% [markdown]
# # Question 9

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df['followers'].corr(users_df['public_repos'])
# Out:
# np.float64(0.34491375135763774)

# %% [markdown]
# # Question 10

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

users_df = pd.read_csv("users.csv")

X = users_df[['public_repos']]  
y = users_df['followers']       

model = LinearRegression()
model.fit(X, y)

followers_per_repo = model.coef_[0]

print(followers_per_repo)
# Out:
# 0.6737356461766962

# %% [markdown]
# # Question 11

# %%
import pandas as pd

repos_df = pd.read_csv("repositories.csv")

correlation = repos_df['has_projects'].corr(repos_df['has_wiki'])

print(correlation)
# Out:
# 0.261897683016074

# %% [markdown]
# # Question 12

# %%
import pandas as pd

df = pd.read_csv("users.csv")

hireable_following = df[df['hireable'] == True]['following'].mean()

non_hireable_following = df[df['hireable'] != True]['following'].mean()

difference = round(hireable_following - non_hireable_following, 3)

print(difference)
# Out:
# 45.869

# %% [markdown]
# # Question 13

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

users_df = pd.read_csv("users.csv")

users_with_bio = users_df[users_df['bio'].notna() & (users_df['bio'] != "")]

users_with_bio['bio_length'] = users_with_bio['bio'].apply(lambda x: len(x.split()))

X = users_with_bio[['bio_length']]  
y = users_with_bio['followers']     

model = LinearRegression()
model.fit(X, y)

followers_per_word = model.coef_[0]

print(followers_per_word)
# Out:
# 2.400439131719209

# %% [markdown]
# # Question 14

# %%
import pandas as pd

repos_df = pd.read_csv("repositories.csv")

repos_df['created_at'] = pd.to_datetime(repos_df['created_at'])

repos_df['is_weekend'] = repos_df['created_at'].dt.dayofweek.isin([5, 6])

weekend_repo_count = repos_df[repos_df['is_weekend']].groupby('login').size()

top_weekend_users = weekend_repo_count.nlargest(5)

top_weekend_user_logins = ','.join(top_weekend_users.index)

print(top_weekend_user_logins)
# Out:
# dpryan79,syzer,ioolkos,maysam,pvillega

# %% [markdown]
# # Question 15

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

fraction_with_email_hireable = users_df[users_df['hireable'] == True]['email'].notna().mean()

fraction_with_email_non_hireable = users_df[users_df['hireable'] != True]['email'].notna().mean()

difference = fraction_with_email_hireable - fraction_with_email_non_hireable

print(difference)
# Out:
# 0.06610564200275221

# %% [markdown]
# # Question 16

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

users_df = users_df.dropna(subset=['name'])
users_df['surname'] = users_df['name'].str.strip().str.split().str[-1]

surname_counts = users_df['surname'].value_counts()

max_count = surname_counts.max()

most_common_surnames = surname_counts[surname_counts == max_count].index.sort_values()

most_common_surnames = ','.join(most_common_surnames)

print(most_common_surnames)
# Out:
# Arnold,Brand,Christensen,Fink,GmbH,Group,Guggisberg,Landolt,Roth,Tan
